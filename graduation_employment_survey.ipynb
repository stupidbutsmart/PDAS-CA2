# %%
# importing modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./datasets/graduate employment survey modified.csv')
dataset = df.copy()
dataset.head()
# Out:
#    year                        university  \
# 0  2013  Nanyang Technological University
# 1  2013  Nanyang Technological University
# 2  2013  Nanyang Technological University
# 3  2013  Nanyang Technological University
# 4  2013  Nanyang Technological University
#
#                                           school  \
# 0  College of Business (Nanyang Business School)
# 1  College of Business (Nanyang Business School)
# 2  College of Business (Nanyang Business School)
# 3  College of Business (Nanyang Business School)
# 4                         College of Engineering
#
#                                         degree employment_rate_overall  \
# 0                     Accountancy and Business                    97.4
# 1  Accountancy (3-yr direct Honours Programme)                    97.1
# 2     Business (3-yr direct Honours Programme)                    90.9
# 3                       Business and Computing                    87.5
# ...

# %%
dataset.columns
# Out:
# Index(['year', 'university', 'school', 'degree', 'employment_rate_overall',
#        'employment_rate_ft_perm', 'basic_monthly_mean', 'basic_monthly_median',
#        'gross_monthly_mean', 'gross_monthly_median',
#        'gross_mthly_25_percentile', 'gross_mthly_75_percentile',
#        'gross_monthly_mean.1', 'gross_monthly_median.1',
#        'gross_mthly_25_percentile.1', 'gross_mthly_75_percentile.1'],
#       dtype='object')

# %% [markdown]
# gross_monthly_mean and gross_monthly_mean.1 probably the same thing vvv

# %%
# proof if needed idk
a = np.array(dataset['gross_monthly_mean'].fillna(np.nan))
b = np.array(dataset['gross_monthly_mean.1'].fillna(np.nan))
print("Indices of differing elements:", np.where(a != b))
print("Indices of NaN gross_monthly_mean:", np.where(a != a)) # this is because np.nan is not equal to itself
print("Indices of NaN gross_monthly_mean.1:", np.where(b != b))
# Out:
# Indices of differing elements: (array([1349, 1350, 1351, 1352, 1353, 1354, 1355, 1356, 1357, 1358, 1359,
#        1360, 1361, 1362, 1363, 1364, 1365, 1366, 1367, 1368, 1369, 1370,
#        1371, 1372, 1373, 1374, 1375, 1376, 1377, 1378, 1379, 1380, 1381,
#        1382, 1383, 1384, 1385, 1386, 1387, 1388, 1389, 1390, 1391, 1392,
#        1393, 1394, 1395, 1396, 1397, 1398, 1399, 1400, 1401, 1402, 1403,
#        1404, 1405, 1406, 1407, 1408, 1409, 1410, 1411, 1412, 1413, 1414,
#        1415, 1416, 1417, 1418, 1419, 1420, 1421, 1422, 1423, 1424, 1425,
#        1426, 1427, 1428, 1429, 1430, 1431, 1432, 1433, 1434, 1435, 1436,
#        1437, 1438, 1439, 1440, 1441, 1442, 1443, 1444, 1445, 1446, 1447,
#        1448, 1449, 1450, 1451, 1452, 1453, 1454, 1455, 1456], dtype=int64),)
# Indices of NaN gross_monthly_mean: (array([1349, 1350, 1351, 1352, 1353, 1354, 1355, 1356, 1357, 1358, 1359,
#        1360, 1361, 1362, 1363, 1364, 1365, 1366, 1367, 1368, 1369, 1370,
# ...

# %%
dataset[['year', 'university', 'school', 'degree', 'gross_monthly_mean', 'gross_monthly_mean.1']][1349:1457]
# Out:
#       year                         university  \
# 1349  2014   Nanyang Technological University
# 1350  2014   Nanyang Technological University
# 1351  2014   Nanyang Technological University
# 1352  2014   Nanyang Technological University
# 1353  2014   Nanyang Technological University
# ...    ...                                ...
# 1452  2014  Singapore Institute of Technology
# 1453  2014  Singapore Institute of Technology
# 1454  2014  Singapore Institute of Technology
# 1455  2014  Singapore Institute of Technology
# 1456  2014  Singapore Institute of Technology
#
#                                              school  \
# 1349  College of Business (Nanyang Business School)
# 1350  College of Business (Nanyang Business School)
# 1351  College of Business (Nanyang Business School)
# 1352  College of Business (Nanyang Business School)
# 1353                         College of Engineering
# ...                                             ...
# ...

# %% [markdown]
# Row 1262

# %%
dataset.iloc[1262]
# Out:
# year                                                year
# university                                    university
# school                                            school
# degree                                            degree
# employment_rate_overall          employment_rate_overall
# employment_rate_ft_perm          employment_rate_ft_perm
# basic_monthly_mean                    basic_monthly_mean
# basic_monthly_median                basic_monthly_median
# gross_monthly_mean                    gross_monthly_mean
# gross_monthly_median                gross_monthly_median
# gross_mthly_25_percentile      gross_mthly_25_percentile
# gross_mthly_75_percentile      gross_mthly_75_percentile
# gross_monthly_mean.1                  gross_monthly_mean
# gross_monthly_median.1              gross_monthly_median
# gross_mthly_25_percentile.1    gross_mthly_25_percentile
# gross_mthly_75_percentile.1    gross_mthly_75_percentile
# Name: 1262, dtype: object

# %%
dataset[dataset.year == 'year']
# Out:
#       year  university  school  degree  employment_rate_overall  \
# 1262  year  university  school  degree  employment_rate_overall
#
#       employment_rate_ft_perm  basic_monthly_mean  basic_monthly_median  \
# 1262  employment_rate_ft_perm  basic_monthly_mean  basic_monthly_median
#
#       gross_monthly_mean  gross_monthly_median  gross_mthly_25_percentile  \
# 1262  gross_monthly_mean  gross_monthly_median  gross_mthly_25_percentile
#
#       gross_mthly_75_percentile gross_monthly_mean.1 gross_monthly_median.1  \
# 1262  gross_mthly_75_percentile   gross_monthly_mean   gross_monthly_median
#
#      gross_mthly_25_percentile.1 gross_mthly_75_percentile.1
# 1262   gross_mthly_25_percentile   gross_mthly_75_percentile

# %% [markdown]
# The dataset repeats

# %%
dataset.iloc[[0, 1263, 2525, 3787, 5049]]
# Out:
#       year                        university  \
# 0     2013  Nanyang Technological University
# 1263  2013  Nanyang Technological University
# 2525  2013  Nanyang Technological University
# 3787  2013  Nanyang Technological University
# 5049  2012  Nanyang Technological University
#
#                                              school                    degree  \
# 0     College of Business (Nanyang Business School)  Accountancy and Business
# 1263  College of Business (Nanyang Business School)  Accountancy and Business
# 2525  College of Business (Nanyang Business School)  Accountancy and Business
# 3787  College of Business (Nanyang Business School)  Accountancy and Business
# 5049  College of Business (Nanyang Business School)  Accountancy and Business
#
#      employment_rate_overall employment_rate_ft_perm basic_monthly_mean  \
# 0                       97.4                    96.1               3701
# 1263                    97.4                    96.1               3701
# ...

# %% [markdown]
# Only 1262 rows of unique data

# %%
df.shape
# Out:
# (5135, 16)

# %%
df[df.duplicated()]
# Out:
#       year                         university  \
# 1263  2013   Nanyang Technological University
# 1264  2013   Nanyang Technological University
# 1265  2013   Nanyang Technological University
# 1266  2013   Nanyang Technological University
# 1267  2013   Nanyang Technological University
# ...    ...                                ...
# 5044  2022  Singapore Institute of Technology
# 5045  2022  Singapore Institute of Technology
# 5046  2022  Singapore Institute of Technology
# 5047  2022  Singapore Institute of Technology
# 5048  2022  Singapore Institute of Technology
#
#                                              school  \
# 1263  College of Business (Nanyang Business School)
# 1264  College of Business (Nanyang Business School)
# 1265  College of Business (Nanyang Business School)
# 1266  College of Business (Nanyang Business School)
# 1267                         College of Engineering
# ...                                             ...
# ...

# %%
dataset.drop_duplicates()
# Out:
#       year                        university  \
# 0     2013  Nanyang Technological University
# 1     2013  Nanyang Technological University
# 2     2013  Nanyang Technological University
# 3     2013  Nanyang Technological University
# 4     2013  Nanyang Technological University
# ...    ...                               ...
# 5130  2012   Singapore Management University
# 5131  2012   Singapore Management University
# 5132  2012   Singapore Management University
# 5133  2012   Singapore Management University
# 5134  2012   Singapore Management University
#
#                                                  school  \
# 0         College of Business (Nanyang Business School)
# 1         College of Business (Nanyang Business School)
# 2         College of Business (Nanyang Business School)
# 3         College of Business (Nanyang Business School)
# 4                                College of Engineering
# ...                                                 ...
# ...
