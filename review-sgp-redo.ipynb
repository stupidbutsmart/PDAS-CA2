# %% [markdown]
# ### Cleaning Indeed Reviews Data
#
# The goal from this dataset is to figure out:
# - How different industries affect the work quality
# - How different ranks affect the work quality
# - How different occupations affect the work quality
#
# ### Basic Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.gofplots import qqplot
import statsmodels.api as sm
import statsmodels.formula.api as smf

import warnings

# Suppress specific warnings
warnings.simplefilter(action="ignore", category=UserWarning)
warnings.simplefilter(action="ignore", category=RuntimeWarning)

# %%
review_data = pd.read_excel('datasets/webscraping_indeed_unique_reviews_24112020.xlsx');

review_data.head(3)
# Out:
#   _OccupationRole    _Rank                                             Author  \
# 0           Sales      NaN  Retail Assistant (Former Employee) - City Hall...
# 1             NaN      NaN  Fashion Advisor (Former Employee) - Jurong poi...
# 2             NaN  Manager  Boutique Manager (Current Employee) - Singapor...
#
#            Company       Date        Employment        Occupation  \
# 0  Charles-&-Keith 2019-11-23   Former Employee  Retail Assistant
# 1  Charles-&-Keith 2020-07-07   Former Employee   Fashion Advisor
# 2  Charles-&-Keith 2020-04-01  Current Employee  Boutique Manager
#
#           Place                                         Review Raw  \
# 0     City Hall  Eazy cash for student who want to earn extra p...
# 1  Jurong point  Working in Charles and Keith is definitely a g...
# 2     Singapore  Charles and Keith is a well known local brand ...
#
#                           Review Removed Punctuation  \
# 0  Eazy cash for student who want to earn extra p...
# 1  Working in Charles and Keith is definitely a g...
# 2  Charles and Keith is a well known local brand ...
#
#                             Review Stopwords Removed  \
# 0  ['eazy', 'cash', 'student', 'want', 'earn', 'e...
# 1  ['working', 'charles', 'keith', 'definitely', ...
# 2  ['charles', 'keith', 'well', 'known', 'local',...
#
#                              ReviewStopwordsRemoved2  \
# 0  eazy cash student want earn extra pocket money...
# 1  working charles keith definitely good opportun...
# 2  charles keith well known local brand singapore...
#
#                                           Table Name  Rating
# 0  webscraping_indeed_reviews_Charles-&-Keith2411...       3
# 1  webscraping_indeed_reviews_Charles-&-Keith2411...       5
# 2  webscraping_indeed_reviews_Charles-&-Keith2411...       3

# %% [markdown]
# ---
#
# We have the following features
#
# ReviewStopwordsRemoved:
#   - This can help us figure out type of benefits
#
# Rank:
#   - Position of the person
#
# Occupation:
#   - What jobs they do. This can help us get the industry
#
# OccupationRole:
#   - Effectively just what department they work at (e.g. a Lawyer in OCBC will still fall under law occupation Role)
#
#
# ---

# %%
review_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3315 entries, 0 to 3314
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   _OccupationRole             1870 non-null   object
#  1   _Rank                       956 non-null    object
#  2   Author                      3315 non-null   object
#  3   Company                     3315 non-null   object
#  4   Date                        3315 non-null   datetime64[ns]
#  5   Employment                  3315 non-null   object
#  6   Occupation                  3305 non-null   object
#  7   Place                       3312 non-null   object
#  8   Review Raw                  3314 non-null   object
#  9   Review Removed Punctuation  3315 non-null   object
#  10  Review Stopwords Removed    3149 non-null   object
#  11  ReviewStopwordsRemoved2     3066 non-null   object
#  12  Table Name                  3315 non-null   object
#  13  Rating                      3315 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(12)
# memory usage: 362.7+ KB

# %%
# Dropping rows and columns
review_data.drop(columns=['Table Name'] , inplace=True)
review_data.dropna(subset=['Occupation' , 'Review Raw' , 'Review Stopwords Removed' ,'ReviewStopwordsRemoved2'] , inplace=True)

# %% [markdown]
# ### Industry and Occupation

# %%
print(review_data['Company'].unique())
print(review_data['_OccupationRole'].unique())
print(review_data['Occupation'].unique())
review_data[['Occupation' , 'Company']]

## There are only 10 unique companies, i can just manually label each based on their industry
## There is alot of occupation
# Out:
# ['Charles-&-Keith' 'Dbs-Bank' 'Giordano' 'Isetann-Department-Store'
#  'M1-Limited' 'Ocbc-Bank' 'Singtel' 'Uniqlo' 'United-Overseas-Bank']
# ['Sales' nan 'Customer Service' 'Product' 'Marketing' 'Technician'
#  'Analysts' 'Business Development' 'Administration' 'Engineering'
#  'Finance/Accounts' 'Project Management']
# ['Retail Assistant' 'Fashion Advisor' 'Boutique Manager' ...
#  'Part Time Bank Teller' 'contract staff' 'Senior Loans Manager']
#                 Occupation               Company
# 0         Retail Assistant       Charles-&-Keith
# 1          Fashion Advisor       Charles-&-Keith
# 2         Boutique Manager       Charles-&-Keith
# 3         Retail Assistant       Charles-&-Keith
# 4          Sales Associate       Charles-&-Keith
# ...                    ...                   ...
# 3310        Senior officer  United-Overseas-Bank
# 3311            Supervisor  United-Overseas-Bank
# 3312     Associate Officer  United-Overseas-Bank
# 3313        contract staff  United-Overseas-Bank
# 3314  Senior Loans Manager  United-Overseas-Bank
#
# [3055 rows x 2 columns]

# %%
## handling industry (easy)
company_to_industry_map = {
  'Charles-&-Keith': 'Fashion Retail',
  'Dbs-Bank': 'Banking & Finance',
  'Giordano': 'Apparel Retail',
  'Isetann-Department-Store': 'General Retail',
  'M1-Limited': 'Telecommunications',
  'Ocbc-Bank': 'Banking & Finance',
  'Singtel': 'Telecommunications',
  'Uniqlo': 'Fashion Retail',
  'United-Overseas-Bank': 'Banking & Finance',
  'Starhub': 'Telecommunications',
}

def createIndustry(company_name):
  global company_to_industry_map
  return company_to_industry_map[company_name]


review_data['Industry'] = review_data['Company'].apply(createIndustry)

review_data['Industry']
# Out:
# 0          Fashion Retail
# 1          Fashion Retail
# 2          Fashion Retail
# 3          Fashion Retail
# 4          Fashion Retail
#               ...
# 3310    Banking & Finance
# 3311    Banking & Finance
# 3312    Banking & Finance
# 3313    Banking & Finance
# 3314    Banking & Finance
# Name: Industry, Length: 3055, dtype: object

# %% [markdown]
# ### Keyword Selection For Occupational Roles

# %%
department_keywords = {
    'Sales': [
        'sales', 'associate', 'account executive', 'business development',
        'representative', 'retail', 'promoter', 'consultant', 'telesales',
        'cashier', 'client advisor', 'store', 'floor staff', 'merchandiser',
        'customer advisor'
    ],
    'Customer Service': [
        'customer service', 'service representative', 'call center', 'support',
        'helpdesk', 'advisor', 'client care', 'relationship officer',
        'service associate', 'service coordinator', 'support specialist',
        'care officer'
    ],
    'Product': [
        'product manager', 'product owner', 'product specialist',
        'product designer', 'vendor', 'merchandiser', 'visual merchandiser',
        'inventory', 'product developer', 'product coordinator'
    ],
    'Marketing': [
        'marketing', 'brand manager', 'digital marketing', 'content creator',
        'seo', 'sem', 'social media', 'campaign manager', 'media buyer',
        'advertising', 'communications', 'promoter', 'public relations'
    ],
    'Technician': [
        'technician', 'maintenance', 'field tech', 'repair',
        'technical support', 'it technician', 'systems technician',
        'network technician', 'engineering tech'
    ],
    'Analysts': [
        'analyst', 'data analyst', 'business analyst', 'research', 'insights',
        'reporting', 'financial analyst', 'market analyst', 'operations analyst'
    ],
    'Business Development': [
        'business development', 'partnership manager', 'growth manager',
        'strategic partnerships', 'sales development', 'alliances',
        'account manager', 'commercial manager'
    ],
    'Administration': [
        'administration', 'admin', 'secretary', 'executive assistant',
        'office manager', 'clerk', 'receptionist', 'coordinator',
        'office assistant', 'administrative officer'
    ],
    'Engineering': [
        'engineer', 'software engineer', 'mechanical engineer',
        'electrical engineer', 'civil engineer', 'systems engineer',
        'network engineer', 'developer', 'full stack', 'backend', 'frontend',
        'technical lead'
    ],
    'Finance/Accounts': [
        'finance', 'accounting', 'accountant', 'financial officer', 'treasury',
        'auditor', 'controller', 'accounts payable', 'accounts receivable',
        'investment', 'banking', 'credit analyst'
    ],
    'Project Management': [
        'project manager', 'program manager', 'scrum master', 'agile coach',
        'project coordinator', 'delivery manager', 'project lead',
        'implementation manager'
    ],
    'Management': [
      'manager',  'supervisor', 'director', 'team lead', 'coordinator',
    'executive', 'administrator', 'chief', 'head of', 'lead',  
    ]
}


def imputeOccupationRole(row):
  value = row['Occupation']
  occupation_role = row['_OccupationRole']

  # no impute non-null values
  if pd.notna(occupation_role):
     return occupation_role

  global department_keywords
  occupation_list = value.lower().split(' ')

  for key , keywords_list in department_keywords.items():

    # going through the keywords for given key
    for keyword in keywords_list:
        if keyword in occupation_list:
           return key
        
        if len(keyword.split(' ')) > 1: # For words like 'program manager'
           if keyword in value.lower():  # direct check if exists in occupation
             return key
  
  ## Unable to group, return nan
  return np.nan


review_data['_OccupationRole'] = review_data.apply(imputeOccupationRole , axis=1)

# %%
review_data[['_OccupationRole' , 'Occupation']]
# Out:
#        _OccupationRole            Occupation
# 0                Sales      Retail Assistant
# 1     Customer Service       Fashion Advisor
# 2           Management      Boutique Manager
# 3                Sales      Retail Assistant
# 4                Sales       Sales Associate
# ...                ...                   ...
# 3310               NaN        Senior officer
# 3311        Management            Supervisor
# 3312             Sales     Associate Officer
# 3313               NaN        contract staff
# 3314        Management  Senior Loans Manager
#
# [3055 rows x 2 columns]

# %% [markdown]
# ### Benefits Extraction

# %%
# Using LDA to extract the occupation departments
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# vectorising the occupations
vectoriser = CountVectorizer(stop_words="english")
data_matrix = vectoriser.fit_transform(review_data['ReviewStopwordsRemoved2'].values.flatten())
features = vectoriser.get_feature_names_out()

# %%
def displayTopicsKeywords(components):
  for index , topic in enumerate(components):
    features_index = topic.argsort()[::-1][:5]
    likely_features = [features[i] for i in features_index]
    print(f"Topic {index + 1}: {likely_features}")

# %%
for k in range(20, 31):
  lda= LatentDirichletAllocation(n_components=k , random_state=42)
  lda.fit(data_matrix)
  print('-----------------------------------------')
  print(f'Results for n-topics = {k}')
  displayTopicsKeywords(lda.components_)
# Out:
# -----------------------------------------
# Results for n-topics = 20
# Topic 1: ['good', 'work', 'job', 'company', 'great']
# Topic 2: ['work', 'working', 'good', 'environment', 'team']
# Topic 3: ['management', 'working', 'communication', 'new', 'culture']
# Topic 4: ['job', 'team', 'customers', 'high', 'engage']
# Topic 5: ['les', 'des', 'très', 'est', 'pour']
# Topic 6: ['people', 'work', 'customers', 'job', 'management']
# Topic 7: ['sales', 'store', 'customer', 'floor', 'customers']
# Topic 8: ['work', 'company', 'day', 'life', 'place']
# Topic 9: ['management', 'company', 'project', 'need', 'learning']
# Topic 10: ['work', 'customers', 'sales', 'dont', 'employees']
# Topic 11: ['job', 'company', 'need', 'working', 'que']
# Topic 12: ['die', 'und', 'dan', 'das', 'managers']
# Topic 13: ['learn', 'really', 'new', 'long', 'clients']
# Topic 14: ['customers', 'customer', 'job', 'service', 'work']
# Topic 15: ['management', 'skills', 'great', 'customer', 'job']
# Topic 16: ['work', 'job', 'time', 'store', 'day']
# Topic 17: ['company', 'employees', 'management', 'work', 'position']
# Topic 18: ['work', 'team', 'customer', 'customers', 'management']
# Topic 19: ['company', 'day', 'work', 'customer', 'people']
# Topic 20: ['good', 'bank', 'work', 'working', 'dbs']
# -----------------------------------------
# Results for n-topics = 21
# Topic 1: ['good', 'work', 'job', 'company', 'great']
# Topic 2: ['work', 'working', 'good', 'team', 'management']
# Topic 3: ['management', 'customers', 'sales', 'youre', 'branch']
# Topic 4: ['job', 'team', 'customers', 'work', 'management']
# Topic 5: ['les', 'des', 'très', 'pour', 'est']
# Topic 6: ['work', 'great', 'job', 'customers', 'people']
# Topic 7: ['store', 'sales', 'job', 'work', 'customers']
# Topic 8: ['work', 'life', 'balance', 'fast', 'day']
# Topic 9: ['management', 'company', 'project', 'learning', 'time']
# Topic 10: ['customers', 'work', 'sales', 'management', 'job']
# Topic 11: ['que', 'job', 'culture', 'new', 'customers']
# Topic 12: ['work', 'working', 'customer', 'company', 'job']
# Topic 13: ['good', 'working', 'environment', 'work', 'really']
# Topic 14: ['working', 'customers', 'work', 'customer', 'job']
# Topic 15: ['management', 'data', 'working', 'job', 'business']
# Topic 16: ['work', 'job', 'time', 'people', 'management']
# Topic 17: ['company', 'employees', 'management', 'uniqlo', 'work']
# Topic 18: ['work', 'management', 'singtel', 'customer', 'good']
# Topic 19: ['day', 'work', 'management', 'face', 'working']
# Topic 20: ['good', 'work', 'bank', 'working', 'dbs']
# Topic 21: ['work', 'working', 'company', 'uniqlo', 'like']
# -----------------------------------------
# Results for n-topics = 22
# Topic 1: ['work', 'good', 'great', 'job', 'management']
# Topic 2: ['work', 'working', 'good', 'learn', 'environment']
# Topic 3: ['management', 'people', 'working', 'staff', 'nous']
# Topic 4: ['customers', 'job', 'clothes', 'customer', 'team']
# Topic 5: ['les', 'très', 'est', 'une', 'des']
# Topic 6: ['people', 'work', 'great', 'customers', 'job']
# Topic 7: ['job', 'working', 'work', 'customers', 'sales']
# Topic 8: ['work', 'company', 'day', 'life', 'place']
# Topic 9: ['management', 'company', 'project', 'time', 'learning']
# Topic 10: ['customers', 'work', 'sales', 'job', 'management']
# Topic 11: ['managers', 'que', 'company', 'work', 'job']
# Topic 12: ['die', 'und', 'das', 'working', 'business']
# Topic 13: ['des', 'les', 'pour', 'vous', 'temps']
# Topic 14: ['customer', 'customers', 'service', 'job', 'sales']
# Topic 15: ['management', 'skills', 'staff', 'job', 'work']
# Topic 16: ['job', 'work', 'store', 'day', 'time']
# Topic 17: ['company', 'management', 'work', 'employees', 'products']
# Topic 18: ['que', 'company', 'customer', 'work', 'skills']
# Topic 19: ['day', 'management', 'customer', 'time', 'work']
# Topic 20: ['work', 'hours', 'working', 'good', 'bank']
# Topic 21: ['work', 'working', 'uniqlo', 'company', 'customer']
# Topic 22: ['working', 'good', 'work', 'environment', 'lot']
# -----------------------------------------
# Results for n-topics = 23
# Topic 1: ['work', 'good', 'job', 'company', 'great']
# Topic 2: ['work', 'team', 'working', 'good', 'job']
# Topic 3: ['management', 'business', 'working', 'des', 'planning']
# Topic 4: ['job', 'customers', 'work', 'team', 'clothes']
# Topic 5: ['les', 'des', 'très', 'pour', 'est']
# Topic 6: ['great', 'work', 'place', 'people', 'job']
# Topic 7: ['fast', 'work', 'sales', 'high', 'paced']
# Topic 8: ['work', 'company', 'day', 'place', 'good']
# Topic 9: ['management', 'project', 'projects', 'learning', 'company']
# Topic 10: ['customers', 'calls', 'work', 'insurance', 'products']
# Topic 11: ['que', 'working', 'new', 'job', 'work']
# Topic 12: ['die', 'und', 'das', 'company', 'manager']
# Topic 13: ['service', 'customer', 'management', 'learn', 'good']
# Topic 14: ['customers', 'customer', 'job', 'day', 'work']
# Topic 15: ['love', 'singtel', 'job', 'skills', 'working']
# Topic 16: ['work', 'job', 'management', 'time', 'store']
# Topic 17: ['employees', 'work', 'company', 'management', 'team']
# Topic 18: ['work', 'company', 'new', 'team', 'management']
# Topic 19: ['company', 'work', 'day', 'management', 'time']
# Topic 20: ['working', 'bank', 'good', 'work', 'environment']
# Topic 21: ['work', 'working', 'good', 'company', 'place']
# Topic 22: ['working', 'good', 'environment', 'work', 'lot']
# Topic 23: ['good', 'work', 'bank', 'company', 'learn']
# -----------------------------------------
# Results for n-topics = 24
# Topic 1: ['good', 'work', 'company', 'job', 'management']
# Topic 2: ['work', 'working', 'good', 'job', 'really']
# Topic 3: ['management', 'open', 'culture', 'learning', 'productive']
# Topic 4: ['job', 'people', 'customers', 'lot', 'learn']
# Topic 5: ['les', 'des', 'très', 'est', 'pour']
# Topic 6: ['great', 'work', 'management', 'people', 'place']
# Topic 7: ['work', 'store', 'job', 'uniqlo', 'retail']
# Topic 8: ['work', 'day', 'life', 'place', 'company']
# Topic 9: ['management', 'company', 'customers', 'time', 'learning']
# Topic 10: ['customers', 'work', 'really', 'help', 'products']
# Topic 11: ['que', 'staffs', 'manager', 'job', 'uma']
# Topic 12: ['die', 'clients', 'und', 'working', 'das']
# Topic 13: ['like', 'management', 'associates', 'great', 'learn']
# Topic 14: ['customers', 'work', 'make', 'working', 'customer']
# Topic 15: ['management', 'great', 'skills', 'culture', 'data']
# Topic 16: ['job', 'work', 'day', 'time', 'people']
# Topic 17: ['employees', 'work', 'company', 'management', 'uniqlo']
# Topic 18: ['work', 'management', 'team', 'company', 'phone']
# Topic 19: ['day', 'time', 'company', 'working', 'customer']
# Topic 20: ['bank', 'good', 'work', 'working', 'dbs']
# Topic 21: ['work', 'working', 'company', 'uniqlo', 'management']
# Topic 22: ['good', 'work', 'working', 'environment', 'learn']
# Topic 23: ['work', 'good', 'company', 'staff', 'balance']
# Topic 24: ['work', 'job', 'customers', 'customer', 'day']
# -----------------------------------------
# Results for n-topics = 25
# Topic 1: ['work', 'job', 'great', 'good', 'management']
# Topic 2: ['work', 'job', 'working', 'customers', 'team']
# Topic 3: ['management', 'need', 'faut', 'par', 'improvement']
# Topic 4: ['job', 'people', 'customers', 'clothes', 'like']
# Topic 5: ['les', 'des', 'très', 'pour', 'est']
# Topic 6: ['people', 'work', 'customer', 'job', 'great']
# Topic 7: ['sales', 'high', 'work', 'floor', 'customers']
# Topic 8: ['day', 'company', 'clients', 'work', 'like']
# Topic 9: ['management', 'project', 'organisation', 'learning', 'time']
# Topic 10: ['work', 'customers', 'managers', 'help', 'job']
# Topic 11: ['company', 'job', 'que', 'managers', 'working']
# Topic 12: ['die', 'und', 'das', 'que', 'dan']
# Topic 13: ['customer', 'management', 'long', 'good', 'new']
# Topic 14: ['customers', 'job', 'work', 'customer', 'sales']
# Topic 15: ['management', 'working', 'great', 'customer', 'skills']
# Topic 16: ['job', 'time', 'work', 'skills', 'people']
# Topic 17: ['management', 'company', 'employees', 'job', 'fair']
# Topic 18: ['customer', 'work', 'customers', 'management', 'store']
# Topic 19: ['day', 'management', 'dont', 'company', 'job']
# Topic 20: ['time', 'working', 'customers', 'good', 'hours']
# Topic 21: ['company', 'work', 'working', 'uniqlo', 'management']
# Topic 22: ['good', 'work', 'working', 'environment', 'place']
# Topic 23: ['work', 'exposure', 'company', 'good', 'role']
# Topic 24: ['work', 'job', 'uniqlo', 'management', 'store']
# Topic 25: ['customers', 'products', 'product', 'knowledge', 'banking']
# -----------------------------------------
# Results for n-topics = 26
# Topic 1: ['work', 'good', 'great', 'management', 'company']
# Topic 2: ['work', 'working', 'environment', 'job', 'colleagues']
# Topic 3: ['des', 'les', 'plus', 'employés', 'temps']
# Topic 4: ['job', 'like', 'team', 'work', 'working']
# Topic 5: ['les', 'très', 'pour', 'est', 'une']
# Topic 6: ['people', 'work', 'great', 'lot', 'place']
# Topic 7: ['sales', 'customers', 'floor', 'work', 'store']
# Topic 8: ['day', 'clients', 'company', 'customers', 'people']
# Topic 9: ['management', 'project', 'company', 'learning', 'time']
# Topic 10: ['calls', 'bank', 'customers', 'phone', 'branch']
# Topic 11: ['job', 'work', 'que', 'customers', 'management']
# Topic 12: ['die', 'und', 'company', 'managers', 'das']
# Topic 13: ['management', 'like', 'store', 'work', 'working']
# Topic 14: ['customer', 'customers', 'job', 'day', 'learned']
# Topic 15: ['management', 'work', 'employees', 'culture', 'great']
# Topic 16: ['work', 'job', 'time', 'people', 'management']
# Topic 17: ['uniqlo', 'company', 'staff', 'employees', 'work']
# Topic 18: ['customer', 'helped', 'work', 'company', 'new']
# Topic 19: ['dont', 'management', 'company', 'managers', 'working']
# Topic 20: ['working', 'bank', 'job', 'good', 'company']
# Topic 21: ['work', 'working', 'company', 'uniqlo', 'good']
# Topic 22: ['working', 'good', 'environment', 'work', 'lot']
# Topic 23: ['good', 'work', 'balance', 'life', 'culture']
# Topic 24: ['work', 'job', 'uniqlo', 'management', 'team']
# Topic 25: ['customers', 'banking', 'products', 'best', 'work']
# Topic 26: ['company', 'work', 'bank', 'day', 'operations']
# -----------------------------------------
# Results for n-topics = 27
# Topic 1: ['good', 'work', 'company', 'job', 'management']
# Topic 2: ['work', 'good', 'working', 'environment', 'learn']
# Topic 3: ['management', 'working', 'les', 'des', 'open']
# Topic 4: ['job', 'like', 'people', 'high', 'asian']
# Topic 5: ['ambiance', 'culture', 'bonne', 'clients', 'market']
# Topic 6: ['people', 'great', 'work', 'job', 'different']
# Topic 7: ['work', 'job', 'time', 'pay', 'working']
# Topic 8: ['day', 'company', 'learned', 'job', 'place']
# Topic 9: ['management', 'company', 'project', 'customers', 'deal']
# Topic 10: ['job', 'customers', 'work', 'sales', 'management']
# Topic 11: ['que', 'managers', 'nous', 'para', 'bien']
# Topic 12: ['company', 'que', 'managers', 'sans', 'des']
# Topic 13: ['les', 'des', 'pour', 'très', 'est']
# Topic 14: ['customers', 'customer', 'job', 'learned', 'sales']
# Topic 15: ['management', 'singtel', 'working', 'staff', 'data']
# Topic 16: ['job', 'work', 'time', 'people', 'store']
# Topic 17: ['employees', 'company', 'work', 'job', 'management']
# Topic 18: ['work', 'customers', 'customer', 'company', 'team']
# Topic 19: ['dont', 'management', 'time', 'work', 'working']
# Topic 20: ['bank', 'good', 'work', 'working', 'dbs']
# Topic 21: ['work', 'working', 'good', 'need', 'customer']
# Topic 22: ['working', 'good', 'work', 'environment', 'sales']
# Topic 23: ['good', 'staff', 'employee', 'management', 'learn']
# Topic 24: ['work', 'job', 'management', 'uniqlo', 'working']
# Topic 25: ['customers', 'products', 'product', 'company', 'banking']
# Topic 26: ['learn', 'customers', 'need', 'role', 'new']
# Topic 27: ['job', 'store', 'working', 'uniqlo', 'lot']
# -----------------------------------------
# Results for n-topics = 28
# Topic 1: ['job', 'work', 'management', 'good', 'company']
# Topic 2: ['work', 'working', 'good', 'management', 'team']
# Topic 3: ['management', 'day', 'lot', 'working', 'need']
# Topic 4: ['like', 'job', 'lot', 'customers', 'people']
# Topic 5: ['work', 'working', 'new', 'bank', 'management']
# Topic 6: ['people', 'work', 'great', 'handle', 'customers']
# Topic 7: ['store', 'sales', 'high', 'time', 'customers']
# Topic 8: ['company', 'day', 'work', 'clients', 'know']
# Topic 9: ['management', 'project', 'projects', 'company', 'customers']
# Topic 10: ['work', 'customers', 'job', 'sales', 'management']
# Topic 11: ['job', 'que', 'working', 'work', 'day']
# Topic 12: ['work', 'job', 'working', 'teamwork', 'clients']
# Topic 13: ['environment', 'like', 'company', 'opportunities', 'knowledge']
# Topic 14: ['customer', 'customers', 'working', 'work', 'job']
# Topic 15: ['employees', 'management', 'culture', 'company', 'great']
# Topic 16: ['job', 'work', 'time', 'people', 'management']
# Topic 17: ['work', 'employees', 'advancement', 'company', 'job']
# Topic 18: ['work', 'management', 'team', 'customer', 'working']
# Topic 19: ['dont', 'managers', 'management', 'store', 'working']
# Topic 20: ['time', 'company', 'bank', 'hours', 'job']
# Topic 21: ['work', 'working', 'company', 'customer', 'management']
# Topic 22: ['good', 'work', 'working', 'environment', 'great']
# Topic 23: ['nice', 'good', 'work', 'staff', 'new']
# Topic 24: ['work', 'job', 'uniqlo', 'management', 'working']
# Topic 25: ['customers', 'product', 'company', 'die', 'products']
# Topic 26: ['company', 'work', 'day', 'standard', 'staff']
# Topic 27: ['working', 'job', 'customer', 'store', 'customers']
# Topic 28: ['les', 'des', 'très', 'pour', 'est']
# -----------------------------------------
# Results for n-topics = 29
# Topic 1: ['job', 'good', 'work', 'company', 'time']
# Topic 2: ['work', 'good', 'working', 'job', 'management']
# Topic 3: ['management', 'people', 'working', 'lot', 'learn']
# Topic 4: ['customers', 'job', 'people', 'management', 'team']
# Topic 5: ['working', 'culture', 'environment', 'management', 'like']
# Topic 6: ['people', 'work', 'management', 'great', 'job']
# Topic 7: ['sales', 'floor', 'customers', 'high', 'customer']
# Topic 8: ['work', 'day', 'life', 'good', 'hours']
# Topic 9: ['management', 'project', 'customers', 'work', 'company']
# Topic 10: ['customers', 'work', 'job', 'calls', 'customer']
# Topic 11: ['job', 'customers', 'working', 'que', 'new']
# Topic 12: ['die', 'und', 'das', 'que', 'nicht']
# Topic 13: ['dans', 'journée', 'learn', 'management', 'clients']
# Topic 14: ['customers', 'customer', 'work', 'working', 'learned']
# Topic 15: ['management', 'data', 'customer', 'customers', 'service']
# Topic 16: ['time', 'job', 'work', 'skills', 'customer']
# Topic 17: ['staffs', 'employees', 'management', 'company', 'people']
# Topic 18: ['work', 'associates', 'new', 'managers', 'customers']
# Topic 19: ['job', 'people', 'company', 'management', 'managers']
# Topic 20: ['working', 'time', 'customer', 'customers', 'bank']
# Topic 21: ['work', 'working', 'uniqlo', 'company', 'great']
# Topic 22: ['working', 'work', 'good', 'environment', 'fun']
# Topic 23: ['good', 'work', 'culture', 'company', 'great']
# Topic 24: ['work', 'job', 'management', 'store', 'uniqlo']
# Topic 25: ['customers', 'products', 'que', 'product', 'company']
# Topic 26: ['customers', 'job', 'sales', 'service', 'work']
# Topic 27: ['job', 'working', 'lot', 'customers', 'store']
# Topic 28: ['les', 'des', 'très', 'est', 'pour']
# Topic 29: ['working', 'job', 'management', 'team', 'ambiance']
# -----------------------------------------
# Results for n-topics = 30
# Topic 1: ['work', 'job', 'good', 'time', 'management']
# Topic 2: ['work', 'working', 'team', 'good', 'management']
# Topic 3: ['management', 'need', 'car', 'business', 'productive']
# Topic 4: ['job', 'customers', 'people', 'need', 'improvement']
# Topic 5: ['les', 'des', 'très', 'est', 'pour']
# Topic 6: ['great', 'work', 'people', 'place', 'job']
# Topic 7: ['work', 'floor', 'sales', 'time', 'day']
# Topic 8: ['work', 'day', 'long', 'hours', 'job']
# Topic 9: ['management', 'company', 'learning', 'time', 'curve']
# Topic 10: ['work', 'customers', 'job', 'day', 'hardest']
# Topic 11: ['que', 'managers', 'job', 'company', 'better']
# Topic 12: ['die', 'und', 'clients', 'das', 'job']
# Topic 13: ['management', 'like', 'environment', 'clients', 'job']
# Topic 14: ['customers', 'job', 'work', 'customer', 'clothes']
# Topic 15: ['job', 'employees', 'management', 'make', 'skills']
# Topic 16: ['work', 'job', 'people', 'good', 'dont']
# Topic 17: ['employees', 'treats', 'staff', 'work', 'training']
# Topic 18: ['work', 'management', 'team', 'associates', 'customer']
# Topic 19: ['day', 'customer', 'work', 'customers', 'company']
# Topic 20: ['good', 'time', 'job', 'work', 'working']
# Topic 21: ['working', 'work', 'company', 'uniqlo', 'store']
# Topic 22: ['working', 'work', 'good', 'environment', 'lot']
# Topic 23: ['good', 'work', 'culture', 'balance', 'company']
# Topic 24: ['work', 'job', 'management', 'uniqlo', 'customer']
# Topic 25: ['customers', 'que', 'company', 'products', 'work']
# Topic 26: ['day', 'team', 'work', 'learn', 'store']
# Topic 27: ['job', 'working', 'day', 'customers', 'like']
# Topic 28: ['new', 'amazing', 'company', 'experience', 'job']
# Topic 29: ['singtel', 'nous', 'management', 'banking', 'comme']
# Topic 30: ['customer', 'customers', 'management', 'project', 'working']

# %%
# Though a brief view of the data, i decided to take the results for n-topic  = 25
# Using the existing values of 
lda= LatentDirichletAllocation(n_components= 25 , random_state=42)
lda.fit(data_matrix)
displayTopicsKeywords(lda.components_)
# Out:
# Topic 1: ['work', 'job', 'great', 'good', 'management']
# Topic 2: ['work', 'job', 'working', 'customers', 'team']
# Topic 3: ['management', 'need', 'faut', 'par', 'improvement']
# Topic 4: ['job', 'people', 'customers', 'clothes', 'like']
# Topic 5: ['les', 'des', 'très', 'pour', 'est']
# Topic 6: ['people', 'work', 'customer', 'job', 'great']
# Topic 7: ['sales', 'high', 'work', 'floor', 'customers']
# Topic 8: ['day', 'company', 'clients', 'work', 'like']
# Topic 9: ['management', 'project', 'organisation', 'learning', 'time']
# Topic 10: ['work', 'customers', 'managers', 'help', 'job']
# Topic 11: ['company', 'job', 'que', 'managers', 'working']
# Topic 12: ['die', 'und', 'das', 'que', 'dan']
# Topic 13: ['customer', 'management', 'long', 'good', 'new']
# Topic 14: ['customers', 'job', 'work', 'customer', 'sales']
# Topic 15: ['management', 'working', 'great', 'customer', 'skills']
# Topic 16: ['job', 'time', 'work', 'skills', 'people']
# Topic 17: ['management', 'company', 'employees', 'job', 'fair']
# Topic 18: ['customer', 'work', 'customers', 'management', 'store']
# Topic 19: ['day', 'management', 'dont', 'company', 'job']
# Topic 20: ['time', 'working', 'customers', 'good', 'hours']
# Topic 21: ['company', 'work', 'working', 'uniqlo', 'management']
# Topic 22: ['good', 'work', 'working', 'environment', 'place']
# Topic 23: ['work', 'exposure', 'company', 'good', 'role']
# Topic 24: ['work', 'job', 'uniqlo', 'management', 'store']
# Topic 25: ['customers', 'products', 'product', 'knowledge', 'banking']

# %%
# After breif analysis, can create a map of what each review main topic is about again its 
topic_groups = {
    'Work Environment & Culture': [1, 2, 3, 8, 21, 22],
    'Management & Staff': [3, 9, 11, 15, 17, 19],
    'Customer Relations': [10, 14, 24, 25],
    'Job & Career Growth': [6, 16, 23],
    'Retail & Store Experience': [4, 7, 18],
    'Foreign': [5, 12, 13],
    'Financial/Banking': [20, 25],
}


topic_weights = lda.transform(data_matrix)
topic_weights = np.argmax(topic_weights , axis=1) + 1 # get the max weight index in each row 

def createReviewTopic(index):
  for key , indices in topic_groups.items():
    if index in indices:
      return key


review_data['topic_weights'] = topic_weights
review_data['review_topics'] = review_data['topic_weights'].apply(createReviewTopic)

# %%
# Using blox text sentiment, i will extract the polarity and subjectivity
from textblob import TextBlob

def extractSentiment(review):
  sentiment = TextBlob(review).sentiment
  return pd.Series([sentiment.polarity , sentiment.subjectivity])

review_data[['review_polarity' , 'review_subjectivity']] = review_data['Review Raw'].apply(extractSentiment)

# %%
## Final display of table head to show all changes made
review_data.head(3)
# Out:
#     _OccupationRole    _Rank  \
# 0             Sales      NaN
# 1  Customer Service      NaN
# 2        Management  Manager
#
#                                               Author          Company  \
# 0  Retail Assistant (Former Employee) - City Hall...  Charles-&-Keith
# 1  Fashion Advisor (Former Employee) - Jurong poi...  Charles-&-Keith
# 2  Boutique Manager (Current Employee) - Singapor...  Charles-&-Keith
#
#         Date        Employment        Occupation         Place  \
# 0 2019-11-23   Former Employee  Retail Assistant     City Hall
# 1 2020-07-07   Former Employee   Fashion Advisor  Jurong point
# 2 2020-04-01  Current Employee  Boutique Manager     Singapore
#
#                                           Review Raw  \
# 0  Eazy cash for student who want to earn extra p...
# 1  Working in Charles and Keith is definitely a g...
# 2  Charles and Keith is a well known local brand ...
#
#                           Review Removed Punctuation  \
# 0  Eazy cash for student who want to earn extra p...
# 1  Working in Charles and Keith is definitely a g...
# 2  Charles and Keith is a well known local brand ...
#
#                             Review Stopwords Removed  \
# 0  ['eazy', 'cash', 'student', 'want', 'earn', 'e...
# 1  ['working', 'charles', 'keith', 'definitely', ...
# 2  ['charles', 'keith', 'well', 'known', 'local',...
#
#                              ReviewStopwordsRemoved2  Rating        Industry  \
# 0  eazy cash student want earn extra pocket money...       3  Fashion Retail
# 1  working charles keith definitely good opportun...       5  Fashion Retail
# 2  charles keith well known local brand singapore...       3  Fashion Retail
#
#    topic_weights               review_topics  review_polarity  \
# 0             24          Customer Relations         0.100000
# 1             22  Work Environment & Culture         0.366667
# 2              2  Work Environment & Culture         0.138889
#
#    review_subjectivity
# 0             0.500000
# 1             0.533333
# 2             0.352778

# %% [markdown]
# ### Plottings

# %%
grouped_by_industry = review_data[['Industry' , 'Rating']].groupby(by='Industry').mean()

# I also want to 'group' the retails tgt
mean_retail_rating = grouped_by_industry.loc[['General Retail' , 'Apparel Retail' ,'Fashion Retail'] , :].median()

# adding to the df
grouped_by_industry.loc['Total Retail'] = mean_retail_rating

# Plottings
X = grouped_by_industry.index
y = grouped_by_industry['Rating'].values

fig , axes = plt.subplots(1 , 2 ,figsize=(12 , 6))

# Bar plot
sns.barplot(x=X , y=y , hue=X , width=0.6 , ax=axes[0])
axes[0].set_xticks(ticks=X , labels=X , rotation=45)
axes[0].set_xlabel('Rating')
axes[0].set_title('Bar plot of Ratings against Industries')


# Box plot
X = review_data['Industry']
sns.violinplot(x=X , y=review_data['Rating'] , ax=axes[1])
axes[1].set_xticks(ticks=X, labels=X , rotation=45)
axes[1].set_title('Violinplot of Ratings')

plt.show()

grouped_by_industry
# Out:
#                       Rating
# Industry
# Apparel Retail      3.841463
# Banking & Finance   3.786580
# Fashion Retail      3.459170
# General Retail      3.805556
# Telecommunications  3.758389
# Total Retail        3.805556

# %%
# Selecting numerical columns along with 'Industry' and 'Company'
categorical_columns = ['Industry', 'Company']
numerical_columns = ['Rating', 'review_polarity', 'review_subjectivity']

# %%
import random  # Import the random module



# Example: Assigning colors dynamically
# Assign a random color
# Generate a random color
def get_random_color():
    return (random.random(), random.random(), random.random())  # RGB tuple

# Loop through each numerical column
for col in numerical_columns:
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))  # 2 rows, 2 columns layout
    
    ## PLOT FOR INDUSTRY ##
    # Histogram + KDE
    sns.histplot(data=review_data, x=col, hue="Industry", bins=30, kde=True, ax=axes[0, 0])
    axes[0, 0].set_title(f"Distribution of {col} by Industry")
    axes[0, 0].set_xlabel(col)
    axes[0, 0].set_ylabel("Count")

    # Q-Q Plot
    for industry in review_data["Industry"].unique():
        random_color = get_random_color()
        sm.qqplot(review_data[review_data["Industry"] == industry][col].dropna(), line="s", fit=True, ax=axes[0, 1], **{'markerfacecolor': random_color}, label=industry)
    axes[0, 1].set_title(f"Q-Q Plot of {col} by Industry")
    axes[0, 1].legend(title="Industry")

    ## PLOT FOR COMPANY ##
    # Histogram + KDE
    sns.histplot(data=review_data, x=col, hue="Company", bins=30, kde=True, ax=axes[1, 0])
    axes[1, 0].set_title(f"Distribution of {col} by Company")
    axes[1, 0].set_xlabel(col)
    axes[1, 0].set_ylabel("Count")

    # Q-Q Plot
    for company in review_data["Company"].unique():
        random_color = get_random_color()
        sm.qqplot(review_data[review_data["Company"] == company][col].dropna(), line="s", fit=True, ax=axes[1, 1], **{'markerfacecolor': random_color}, label=company)
    axes[1, 1].set_title(f"Q-Q Plot of {col} by Company")
    axes[1, 1].legend(title="Company")

    # Adjust layout for better visualization
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ##### Polarity
#
# All of the plots are generally normally distributed
#
# Though there is some negative skewed data, which are most likely outliers
#
# Looking closely at the plots the negative skewed data is from Fashion Retail
#
# However overall, the data seems to be congregated between 0 to 0.25, suggesting that most reviews are mildly or completely neutral
#
# ##### Subjectivity
#
# For all the plots, there seems to be a concentration around the 0.4-0.6 region, suggesting that most of the reviews are moderately subjective
#
# This can mean that most of the reviews are opinions, less 'factually spoken'
#
# ##### Topic Weights
#
# For **Banking and Finance**, most of the reviews are regarding Topic 22 (Work Environment)
#
# For **Fashion Retail**, most of the reviews are regarding Topic 24 (Customer Relations)
#
# With both its polarity peaking around 0.2 to 0.3 it suggests that its respective topics are quite good

# %%
industries = review_data['Industry'].unique()


for industry in industries:
  condition = review_data['Industry'] == industry
  industry_polarity_group = review_data[condition].pivot_table(columns='review_topics' , values='review_polarity' , aggfunc='mean')
  industry_subjectivity_group = review_data[condition].pivot_table(columns='review_topics' , values='review_subjectivity' , aggfunc='mean')

  fig , axes = plt.subplots(1 , 2 , figsize=(16 , 4))

  plt.suptitle(f'Plots for {industry}')

  X = industry_polarity_group.columns
  y = industry_polarity_group.values.flatten()
  sns.barplot(x=X , y=y , ax=axes[0] , hue=X)
  axes[0].set_title('Polarity')
  axes[0].set_xticklabels(axes[0].get_xticklabels() , rotation=80)

  X = industry_subjectivity_group.columns
  y = industry_subjectivity_group.values.flatten()
  sns.barplot(x=X , y=y , ax=axes[1] , hue=X)
  axes[1].set_title('Subjectivity')
  axes[1].set_xticklabels(axes[1].get_xticklabels() , rotation=80)

  plt.show()

# %% [markdown]
# From all of the plots **Work Environment and Culture** Seems to be some of the more positive things written about
#
# They all have a polarity roughly around 0.3 (which is around moderately positive)
#
# Both the Telecommunications and General Retail Industry seems to have the highest **Job and Carerr Growth Opportunities**
#
# They have a polarity of roughly 0.23 (which is around slightly positive)
#
#
# All of the plots have a moderate Subjectivity of around 0.3 to 0.5. This can suggest that they are speaking from experience (hence such a high subjectivity). This can mean give more support to their reviews being truthful and honest.
#
# The High number of **Foreign Reviews** from General Retail Suggests that it may be saturated by foreigners

# %%
# Another thing we can try to to group review topics via rating
industries = review_data['Industry'].unique()

fig , axes = plt.subplots(3 , 2 , figsize=(16 , 22))
axes = axes.flatten()

for i , industry in enumerate( industries):
  condition = review_data['Industry'] == industry
  industry_polarity_group = review_data[condition].pivot_table(columns='review_topics' , values='Rating' , aggfunc='mean')

  X = industry_polarity_group.columns
  y = industry_polarity_group.values.flatten()
  sns.barplot(x=X , y=y , ax=axes[i] , hue=X)
  axes[i].set_title(f'Rating by review_topic for {industry}')
  axes[i].set_xticklabels(axes[i].get_xticklabels() , rotation=80)

plt.subplots_adjust(hspace=0.8)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Define a color palette
palette = "Set2"

# Function to print and annotate max and min outliers **for each category**
def annotate_outliers(ax, category_col, value_col):
    grouped_outliers = review_data.groupby(category_col)

    for category, group in grouped_outliers:
        if group.empty:
            continue  # Skip if no outliers exist

        # Get max and min outliers within each category
        max_flier = group[value_col].max()
        min_flier = group[value_col].min()

        # Get index of max and min outliers
        max_flier_index = group[value_col].idxmax()
        min_flier_index = group[value_col].idxmin()

        # Print max and min outliers per category
        print(f"\nOutliers for {value_col} in {category_col} - {category}:")
        print(f"  Max Outlier: {max_flier:.2f}")
        print(f"  Min Outlier: {min_flier:.2f}")

        # Get coordinates
        x_max = category
        y_max = group.loc[max_flier_index, value_col]
        x_min = category
        y_min = group.loc[min_flier_index, value_col]

        # Define offsets
        offset_max = (y_max * 0.015) if y_max != 0 else 0.1  # 5% of value or 0.1 if y=0
        offset_min = (y_min * 0.015) if y_min != 0 else -0.1  # 5% of value or -0.1 if y=0

        # Annotate points with offsets
        ax.text(x_max, y_max + offset_max, f'{max_flier:.2f}', color='green', fontsize=10, ha='center', va='bottom', fontweight='bold')
        ax.text(x_min, y_min - offset_min, f'{min_flier:.2f}', color='green', fontsize=10, ha='center', va='top', fontweight='bold')


# Create subplots
fig, axMany = plt.subplots(2, len(numerical_columns), figsize=(20, 10), squeeze=False)

# Plot numerical columns grouped by Industry (First Row)
for colCnt, item in enumerate(numerical_columns):
    ax = axMany[0, colCnt]
    
    sns.boxplot(x=review_data["Industry"], y=review_data[item], ax=ax, hue=review_data["Industry"],palette=palette,
                flierprops={'marker': 'o', 'color': 'red', 'markersize': 5})
    
    ax.set_title(f"{item} by Industry")
    ax.tick_params(axis='x', rotation=90)

    # Annotate and print max/min outliers per category
    annotate_outliers(ax, "Industry", item)

# Plot numerical columns grouped by Company (Second Row)
for colCnt, item in enumerate(numerical_columns):
    ax = axMany[1, colCnt]

    sns.boxplot(x=review_data["Company"], y=review_data[item], ax=ax, hue=review_data["Company"],palette=palette,
                flierprops={'marker': 'o', 'color': 'red', 'markersize': 5})
    
    ax.set_title(f"{item} by Company")
    ax.tick_params(axis='x', rotation=90)

    # Annotate and print max/min outliers per category
    annotate_outliers(ax, "Company", item)

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# Outliers for Rating in Industry - Apparel Retail:
#   Max Outlier: 5.00
#   Min Outlier: 1.00
#
# Outliers for Rating in Industry - Banking & Finance:
#   Max Outlier: 5.00
#   Min Outlier: 1.00
#
# Outliers for Rating in Industry - Fashion Retail:
#   Max Outlier: 5.00
#   Min Outlier: 1.00
#
# Outliers for Rating in Industry - General Retail:
#   Max Outlier: 5.00
#   Min Outlier: 1.00
#
# Outliers for Rating in Industry - Telecommunications:
#   Max Outlier: 5.00
#   Min Outlier: 1.00
#
# Outliers for review_polarity in Industry - Apparel Retail:
#   Max Outlier: 0.85
#   Min Outlier: -0.50
#
# Outliers for review_polarity in Industry - Banking & Finance:
#   Max Outlier: 0.91
#   Min Outlier: -0.54
#
# Outliers for review_polarity in Industry - Fashion Retail:
#   Max Outlier: 1.00
#   Min Outlier: -1.00
#
# Outliers for review_polarity in Industry - General Retail:
#   Max Outlier: 0.85
#   Min Outlier: -0.12
#
# Outliers for review_polarity in Industry - Telecommunications:
#   Max Outlier: 1.00
#   Min Outlier: -0.23
#
# Outliers for review_subjectivity in Industry - Apparel Retail:
#   Max Outlier: 1.00
#   Min Outlier: 0.00
#
# Outliers for review_subjectivity in Industry - Banking & Finance:
#   Max Outlier: 1.00
#   Min Outlier: 0.00
#
# Outliers for review_subjectivity in Industry - Fashion Retail:
#   Max Outlier: 1.00
#   Min Outlier: 0.00
#
# Outliers for review_subjectivity in Industry - General Retail:
#   Max Outlier: 1.00
#   Min Outlier: 0.00
#
# Outliers for review_subjectivity in Industry - Telecommunications:
#   Max Outlier: 1.00
#   Min Outlier: 0.00
#
# Outliers for Rating in Company - Charles-&-Keith:
#   Max Outlier: 5.00
#   Min Outlier: 1.00
#
# Outliers for Rating in Company - Dbs-Bank:
#   Max Outlier: 5.00
#   Min Outlier: 1.00
#
# Outliers for Rating in Company - Giordano:
#   Max Outlier: 5.00
#   Min Outlier: 1.00
#
# Outliers for Rating in Company - Isetann-Department-Store:
#   Max Outlier: 5.00
#   Min Outlier: 1.00
#
# Outliers for Rating in Company - M1-Limited:
#   Max Outlier: 5.00
#   Min Outlier: 1.00
#
# Outliers for Rating in Company - Ocbc-Bank:
#   Max Outlier: 5.00
#   Min Outlier: 1.00
#
# Outliers for Rating in Company - Singtel:
#   Max Outlier: 5.00
#   Min Outlier: 1.00
#
# Outliers for Rating in Company - Uniqlo:
#   Max Outlier: 5.00
#   Min Outlier: 1.00
#
# Outliers for Rating in Company - United-Overseas-Bank:
#   Max Outlier: 5.00
#   Min Outlier: 1.00
#
# Outliers for review_polarity in Company - Charles-&-Keith:
#   Max Outlier: 0.70
#   Min Outlier: -0.40
#
# Outliers for review_polarity in Company - Dbs-Bank:
#   Max Outlier: 0.91
#   Min Outlier: -0.36
#
# Outliers for review_polarity in Company - Giordano:
#   Max Outlier: 0.85
#   Min Outlier: -0.50
#
# Outliers for review_polarity in Company - Isetann-Department-Store:
#   Max Outlier: 0.85
#   Min Outlier: -0.12
#
# Outliers for review_polarity in Company - M1-Limited:
#   Max Outlier: 0.65
#   Min Outlier: -0.16
#
# Outliers for review_polarity in Company - Ocbc-Bank:
#   Max Outlier: 0.90
#   Min Outlier: -0.54
#
# Outliers for review_polarity in Company - Singtel:
#   Max Outlier: 1.00
#   Min Outlier: -0.23
#
# Outliers for review_polarity in Company - Uniqlo:
#   Max Outlier: 1.00
#   Min Outlier: -1.00
#
# Outliers for review_polarity in Company - United-Overseas-Bank:
#   Max Outlier: 0.91
#   Min Outlier: -0.35
#
# Outliers for review_subjectivity in Company - Charles-&-Keith:
#   Max Outlier: 0.80
#   Min Outlier: 0.00
#
# Outliers for review_subjectivity in Company - Dbs-Bank:
#   Max Outlier: 1.00
#   Min Outlier: 0.00
#
# Outliers for review_subjectivity in Company - Giordano:
#   Max Outlier: 1.00
#   Min Outlier: 0.00
#
# Outliers for review_subjectivity in Company - Isetann-Department-Store:
#   Max Outlier: 1.00
#   Min Outlier: 0.00
#
# Outliers for review_subjectivity in Company - M1-Limited:
#   Max Outlier: 1.00
#   Min Outlier: 0.00
#
# Outliers for review_subjectivity in Company - Ocbc-Bank:
#   Max Outlier: 1.00
#   Min Outlier: 0.00
#
# Outliers for review_subjectivity in Company - Singtel:
#   Max Outlier: 1.00
#   Min Outlier: 0.00
#
# Outliers for review_subjectivity in Company - Uniqlo:
#   Max Outlier: 1.00
#   Min Outlier: 0.00
#
# Outliers for review_subjectivity in Company - United-Overseas-Bank:
#   Max Outlier: 1.00
#   Min Outlier: 0.00

# %%
#Remove the outlier box the IQR
Q1 = review_data[numerical_columns].quantile(0.25)
Q3 = review_data[numerical_columns].quantile(0.75)
IQR = Q3 - Q1

# Filtering the data to remove outliers
df_out = review_data[~((review_data[numerical_columns] < (Q1 - 1.5 * IQR)) | (review_data[numerical_columns] > (Q3 + 1.5 * IQR))).any(axis=1)]

# Print the shape before and after outlier removal
print("Original Data Shape:", review_data.shape)
print("Data Shape After Outlier Removal:", df_out.shape)

# Define a color palette
palette = "Set2"

# Function to print and annotate max and min outliers **for each category**
def annotate_outliers(ax, category_col, value_col):
    grouped_outliers = df_out.groupby(category_col)

    for category, group in grouped_outliers:
        if group.empty:
            continue  # Skip if no outliers exist

        # Get max and min outliers within each category
        max_flier = group[value_col].max()
        min_flier = group[value_col].min()

        # Get index of max and min outliers
        max_flier_index = group[value_col].idxmax()
        min_flier_index = group[value_col].idxmin()

        # Print max and min outliers per category
        print(f"\nOutliers for {value_col} in {category_col} - {category}:")
        print(f"  Max Outlier: {max_flier:.2f}")
        print(f"  Min Outlier: {min_flier:.2f}")

        # Get coordinates
        x_max = category
        y_max = group.loc[max_flier_index, value_col]
        x_min = category
        y_min = group.loc[min_flier_index, value_col]

        # Define offsets
        offset_max = (y_max * 0.015) if y_max != 0 else 0.1  # 5% of value or 0.1 if y=0
        offset_min = (y_min * 0.015) if y_min != 0 else -0.1  # 5% of value or -0.1 if y=0

        # Annotate points with offsets
        ax.text(x_max, y_max + offset_max, f'{max_flier:.2f}', color='green', fontsize=10, ha='center', va='bottom', fontweight='bold')
        ax.text(x_min, y_min - offset_min, f'{min_flier:.2f}', color='green', fontsize=10, ha='center', va='top', fontweight='bold')


# Create subplots
fig, axMany = plt.subplots(2, len(numerical_columns), figsize=(20, 10), squeeze=False)

# Plot numerical columns grouped by Industry (First Row)
for colCnt, item in enumerate(numerical_columns):
    ax = axMany[0, colCnt]
    
    sns.boxplot(x=df_out["Industry"], y=df_out[item], ax=ax, hue=df_out["Industry"],palette=palette,
                flierprops={'marker': 'o', 'color': 'red', 'markersize': 5})
    
    ax.set_title(f"{item} by Industry")
    ax.tick_params(axis='x', rotation=90)

    # Annotate and print max/min outliers per category
    annotate_outliers(ax, "Industry", item)

# Plot numerical columns grouped by Company (Second Row)
for colCnt, item in enumerate(numerical_columns):
    ax = axMany[1, colCnt]

    sns.boxplot(x=df_out["Company"], y=df_out[item], ax=ax, hue=df_out["Company"],palette=palette,
                flierprops={'marker': 'o', 'color': 'red', 'markersize': 5})
    
    ax.set_title(f"{item} by Company")
    ax.tick_params(axis='x', rotation=90)

    # Annotate and print max/min outliers per category
    annotate_outliers(ax, "Company", item)

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# Original Data Shape: (3055, 18)
# Data Shape After Outlier Removal: (2623, 18)
#
# Outliers for Rating in Industry - Apparel Retail:
#   Max Outlier: 5.00
#   Min Outlier: 2.00
#
# Outliers for Rating in Industry - Banking & Finance:
#   Max Outlier: 5.00
#   Min Outlier: 2.00
#
# Outliers for Rating in Industry - Fashion Retail:
#   Max Outlier: 5.00
#   Min Outlier: 2.00
#
# Outliers for Rating in Industry - General Retail:
#   Max Outlier: 5.00
#   Min Outlier: 2.00
#
# Outliers for Rating in Industry - Telecommunications:
#   Max Outlier: 5.00
#   Min Outlier: 2.00
#
# Outliers for review_polarity in Industry - Apparel Retail:
#   Max Outlier: 0.63
#   Min Outlier: -0.30
#
# Outliers for review_polarity in Industry - Banking & Finance:
#   Max Outlier: 0.80
#   Min Outlier: -0.36
#
# Outliers for review_polarity in Industry - Fashion Retail:
#   Max Outlier: 0.80
#   Min Outlier: -0.35
#
# Outliers for review_polarity in Industry - General Retail:
#   Max Outlier: 0.80
#   Min Outlier: -0.12
#
# Outliers for review_polarity in Industry - Telecommunications:
#   Max Outlier: 0.77
#   Min Outlier: -0.21
#
# Outliers for review_subjectivity in Industry - Apparel Retail:
#   Max Outlier: 0.77
#   Min Outlier: 0.20
#
# Outliers for review_subjectivity in Industry - Banking & Finance:
#   Max Outlier: 0.90
#   Min Outlier: 0.10
#
# Outliers for review_subjectivity in Industry - Fashion Retail:
#   Max Outlier: 0.90
#   Min Outlier: 0.10
#
# Outliers for review_subjectivity in Industry - General Retail:
#   Max Outlier: 0.80
#   Min Outlier: 0.19
#
# Outliers for review_subjectivity in Industry - Telecommunications:
#   Max Outlier: 0.90
#   Min Outlier: 0.10
#
# Outliers for Rating in Company - Charles-&-Keith:
#   Max Outlier: 5.00
#   Min Outlier: 2.00
#
# Outliers for Rating in Company - Dbs-Bank:
#   Max Outlier: 5.00
#   Min Outlier: 2.00
#
# Outliers for Rating in Company - Giordano:
#   Max Outlier: 5.00
#   Min Outlier: 2.00
#
# Outliers for Rating in Company - Isetann-Department-Store:
#   Max Outlier: 5.00
#   Min Outlier: 2.00
#
# Outliers for Rating in Company - M1-Limited:
#   Max Outlier: 5.00
#   Min Outlier: 2.00
#
# Outliers for Rating in Company - Ocbc-Bank:
#   Max Outlier: 5.00
#   Min Outlier: 2.00
#
# Outliers for Rating in Company - Singtel:
#   Max Outlier: 5.00
#   Min Outlier: 2.00
#
# Outliers for Rating in Company - Uniqlo:
#   Max Outlier: 5.00
#   Min Outlier: 2.00
#
# Outliers for Rating in Company - United-Overseas-Bank:
#   Max Outlier: 5.00
#   Min Outlier: 2.00
#
# Outliers for review_polarity in Company - Charles-&-Keith:
#   Max Outlier: 0.70
#   Min Outlier: -0.08
#
# Outliers for review_polarity in Company - Dbs-Bank:
#   Max Outlier: 0.80
#   Min Outlier: -0.36
#
# Outliers for review_polarity in Company - Giordano:
#   Max Outlier: 0.63
#   Min Outlier: -0.30
#
# Outliers for review_polarity in Company - Isetann-Department-Store:
#   Max Outlier: 0.80
#   Min Outlier: -0.12
#
# Outliers for review_polarity in Company - M1-Limited:
#   Max Outlier: 0.59
#   Min Outlier: -0.08
#
# Outliers for review_polarity in Company - Ocbc-Bank:
#   Max Outlier: 0.80
#   Min Outlier: -0.27
#
# Outliers for review_polarity in Company - Singtel:
#   Max Outlier: 0.77
#   Min Outlier: -0.21
#
# Outliers for review_polarity in Company - Uniqlo:
#   Max Outlier: 0.80
#   Min Outlier: -0.35
#
# Outliers for review_polarity in Company - United-Overseas-Bank:
#   Max Outlier: 0.70
#   Min Outlier: -0.35
#
# Outliers for review_subjectivity in Company - Charles-&-Keith:
#   Max Outlier: 0.80
#   Min Outlier: 0.11
#
# Outliers for review_subjectivity in Company - Dbs-Bank:
#   Max Outlier: 0.90
#   Min Outlier: 0.10
#
# Outliers for review_subjectivity in Company - Giordano:
#   Max Outlier: 0.77
#   Min Outlier: 0.20
#
# Outliers for review_subjectivity in Company - Isetann-Department-Store:
#   Max Outlier: 0.80
#   Min Outlier: 0.19
#
# Outliers for review_subjectivity in Company - M1-Limited:
#   Max Outlier: 0.88
#   Min Outlier: 0.15
#
# Outliers for review_subjectivity in Company - Ocbc-Bank:
#   Max Outlier: 0.88
#   Min Outlier: 0.10
#
# Outliers for review_subjectivity in Company - Singtel:
#   Max Outlier: 0.90
#   Min Outlier: 0.10
#
# Outliers for review_subjectivity in Company - Uniqlo:
#   Max Outlier: 0.90
#   Min Outlier: 0.10
#
# Outliers for review_subjectivity in Company - United-Overseas-Bank:
#   Max Outlier: 0.89
#   Min Outlier: 0.10

# %%
# Import the statsmodels formula API
import statsmodels.formula.api as smf

# Extract relevant data
x = review_data['review_subjectivity']
y = review_data['review_polarity']

model = smf.ols('review_polarity ~ review_subjectivity', data=review_data).fit()

# Print the model summary
print(model.params)
print(model.summary())


# Fit a linear regression using np.polyfit
coefficients = np.polyfit(x, y, 1)
line_of_best_fit = np.poly1d(coefficients)

# Plot the scatter plot
plt.scatter(x, y, alpha=0.5, label="Data Points")
plt.xlabel('Review Subjectivity')
plt.ylabel('Review Polarity')
plt.title('Review Polarity vs. Review Subjectivity')

# Plot the best-fit line
plt.plot(x, line_of_best_fit(x), color='red', label="Best-Fit Line")

# Add the equation to the plot
equation = f'y = {coefficients[0]:.2f}x + {coefficients[1]:.2f}'
plt.text(min(x), max(y) - 0.1, equation, color='red', fontsize=12)

# Show the plot
plt.legend()
plt.show()
# Out:
# Intercept              0.015652
# review_subjectivity    0.444559
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        review_polarity   R-squared:                       0.164
# Model:                            OLS   Adj. R-squared:                  0.163
# Method:                 Least Squares   F-statistic:                     596.8
# Date:                Sun, 09 Feb 2025   Prob (F-statistic):          1.54e-120
# Time:                        16:57:12   Log-Likelihood:                 548.20
# No. Observations:                3055   AIC:                            -1092.
# Df Residuals:                    3053   BIC:                            -1080.
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.0157      0.010      1.644      0.100      -0.003       0.034
# review_subjectivity     0.4446      0.018     24.429      0.000       0.409       0.480
# ==============================================================================
# Omnibus:                      565.232   Durbin-Watson:                   1.822
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2460.144
# Skew:                          -0.836   Prob(JB):                         0.00
# Kurtosis:                       7.066   Cond. No.                         6.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Group by 'review_topics' and calculate the mean for numerical columns
df_grouped = review_data.groupby('review_topics').mean(numeric_only=True)

# Reset index to make 'review_topics' a column
df_grouped_reset = df_grouped.reset_index()

# Fit the OLS model
model = smf.ols("topic_weights ~ C(review_topics)", data=df_grouped_reset).fit()

# Display the model summary
model_summary = model.summary()

# Plot bar chart for topic_weights by review_topics
plt.figure(figsize=(12, 6))
plt.bar(df_grouped.index, df_grouped['topic_weights'], color='skyblue', edgecolor='black')
plt.xlabel("Review Topics")
plt.ylabel("Topic Weights")
plt.title("Topic Weights by Review Topics")
plt.xticks(rotation=45, ha='right')  # Rotate x labels for better visibility
plt.grid(axis='y', alpha=0.75)
plt.show()

# Display the model summary
model_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          topic_weights   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Sun, 09 Feb 2025   Prob (F-statistic):                nan
# Time:                        16:57:13   Log-Likelihood:                 221.81
# No. Observations:                   7   AIC:                            -429.6
# Df Residuals:                       0   BIC:                            -430.0
# Df Model:                           6
# Covariance Type:            nonrobust
# ==================================================================================================================
#                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# Intercept                                         22.1049        inf          0        nan         nan         nan
# C(review_topics)[T.Financial/Banking]             -2.1049        inf         -0        nan         nan         nan
# C(review_topics)[T.Foreign]                      -13.6958        inf         -0        nan         nan         nan
# C(review_topics)[T.Job & Career Growth]           -7.4857        inf         -0        nan         nan         nan
# C(review_topics)[T.Management & Staff]            -7.7638        inf         -0        nan         nan         nan
# C(review_topics)[T.Retail & Store Experience]    -13.1356        inf         -0        nan         nan         nan
# C(review_topics)[T.Work Environment & Culture]    -8.6427        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.692
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.615
# Skew:                           0.028   Prob(JB):                        0.735
# Kurtosis:                       1.548   Cond. No.                         7.87
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
